# %%
import bs4
import urllib
import urllib3
import pandas as pd

# %%
main_links = ['https://www.ricardoanaya.com.mx/sala-de-prensa']
for page in range(2,16):
    main_links.append('https://www.ricardoanaya.com.mx/sala-de-prensa/page/'+ str(page))

# %%
def make_soup(myurl):
    if '“' not in myurl:
        pm = urllib3.PoolManager()
        html = pm.urlopen(url = myurl, method = 'GET').data
        return bs4.BeautifulSoup(html, 'html5lib')

# %%
def get_anaya(page, results_list):
    for link in page.find_all('a', rel= "Index, Follow"):
        results_list.append('https://www.ricardoanaya.com.mx' + link.get('href'))

# %%
all_links = []

# %%
for url in main_links:
    soup = make_soup(url)
    get_anaya(soup, all_links)
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
def get_text(soup_page, delete = ['\n', '\xa0']):
    if soup_page.find('div',style="float: left; width: 100%; margin-bottom: 15px;"):
        my_string = soup.find('div', style="float: left; width: 100%; margin-bottom: 15px;").text
        for sign in delete:
            my_string = my_string.replace(sign,'')
        my_string = my_string.replace('\t',' ')
        return my_string

# %%
def get_date(soup_page):
    if soup_page:
        if soup_page.find('div',style="float: left; width: 100%; margin-bottom: 15px;"):
            date = soup_page.find('div', style="float: left; width: 100%; margin-bottom: 15px;").find_all('div')
            if len(date) > 1:
                return date[1].text
            else:
                return ''

# %%
dates = []
for link in all_links:
    soup = make_soup(link)
    dates.append(get_date(soup))
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
len(dates)
# Out:
# 134

# %%
anaya_texts = []
for link in all_links:
    link_soup = make_soup(link)
    date = get_date(link_soup)
    text = get_text(link_soup)
    anaya_texts.append([date, text])
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\jesus\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
anaya_df = pd.DataFrame(anaya_texts, columns=['date', 'text'])

# %%
anaya_df
# Out:
#                                                 date  \
# 0           Morelia, Michoacán, a 26 de mayo de 2018
# 1           Morelia, Michoacán, a 26 de mayo de 2018
# 2           Sahuayo, Michoacán, a 26 de mayo de 2018
# 3               Tepic, Nayarit, a 25 de mayo de 2018
# 4   Ecatepec, Estado de México, a 25 de mayo de 2018
# 5   Atizapán, Estado de México, a 24 de mayo de 2018
# 6             Ciudad de México, a 24 de mayo de 2018
# 7             Ciudad de México, a 23 de mayo de 2018
# 8         Guadalajara, Jalisco, a 23 de mayo de 2018
# 9         Guadalajara, Jalisco, a 23 de mayo de 2018
# 10              Colima, Colima, a 22 de mayo de 2018
# 11            Ciudad de México, a 21 de mayo de 2018
# 12    Tijuana, Baja California, a 20 de mayo de 2018
# 13                                19 de mayo de 2018
# 14    Tijuana, Baja California, a 18 de mayo de 2018
# 15          Hermosillo, Sonora, a 17 de mayo de 2018
# 16            Ciudad de México, a 17 de mayo de 2017
# ...

# %%
anaya_df.to_csv('anaya_bis.csv', index=False, encoding='utf-16')
